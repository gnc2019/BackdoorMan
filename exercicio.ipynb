# %%
disponiveis = ["Dom Casmurro","1984","O Pequeno Príncipe","A Revolução dos Bichos","O Alquimista"]
emprestados = []
reservados = []

disponiveis.remove("1984")
print("Lista dos disponiveis {}".format(disponiveis))

emprestados.append("1984")
print("Lista dos emprestados {}".format(emprestados))


disponiveis.remove("O Alquimista")
reservados.append("O Alquimista")
print("Lista dos reservados {}".format(reservados))

reservados.remove("O Alquimista")
emprestados.append("O Alquimista")
print("Lista dos emprestados {}".format(emprestados))

emprestados.remove('1984')
disponiveis.append("1984")
print("Lista dos disponiveis {}".format(disponiveis))

disponiveis.sort()
emprestados.sort()
print("Lista dos disponiveis {}".format(disponiveis))
print("Lista dos emprestados {}".format(emprestados))


print(len(disponiveis))
print(len(emprestados))
print(len(reservados))
# Out:
# Lista dos disponiveis ['Dom Casmurro', 'O Pequeno Príncipe', 'A Revolução dos Bichos', 'O Alquimista']
# Lista dos emprestados ['1984']
# Lista dos reservados ['O Alquimista']
# Lista dos emprestados ['1984', 'O Alquimista']
# Lista dos disponiveis ['Dom Casmurro', 'O Pequeno Príncipe', 'A Revolução dos Bichos', '1984']
# Lista dos disponiveis ['1984', 'A Revolução dos Bichos', 'Dom Casmurro', 'O Pequeno Príncipe']
# Lista dos emprestados ['O Alquimista']
# 4
# 1
# 0

# %%
disponiveis = ["Dom Casmurro","1984","O Pequeno Príncipe","A Revolução dos Bichos","O Alquimista"]
emprestados = []
reservados = []


# for i in disponiveis[1:2]:
#     print(i)
livro = str(input("Digite o nome do livro"))
destino = str(input("Vai querer emprestado ou fazer reserva?"))
print(destino)
if livro in disponiveis or destino == "emprestado":
    emprestados.append(livro)
    disponiveis.remove(livro)
else:
    reservados.append(livro)
    disponiveis.remove(livro)
print("livro emprestado: {}".format(emprestados))
print("livro reservado: {}".format(reservados))
print(disponiveis)
# Out:
# emprestado
# livro emprestado: ['1984']
# livro reservado: []
# ['Dom Casmurro', 'O Pequeno Príncipe', 'A Revolução dos Bichos', 'O Alquimista']

# %%
nome = []
qtde = []
preco = []
total_vendas = 0
mais_vendido_qtde = 0
mais_vendido_nome = ""

qtde_produtos_vendidos = int(input("Quantos produtos foram vendidos? "))
i = 0
for i in range(qtde_produtos_vendidos):
        nome_produto = str(input("Digite o nome do produto: "))
        qtde_produtos = int(input("Informe a quantidade vendida:"))
        preco_unitario = float(input("Infome o preço unitário:"))
        nome.append(nome_produto)
        qtde.append(qtde_produtos)
        preco.append(preco_unitario)

for i in range(qtde_produtos_vendidos):
        sub_total = qtde[i] * preco[i]
        total_vendas = total_vendas + sub_total
    
if qtde[i] > mais_vendido_qtde:
    mais_vendido_nome = nome[i]
    mais_vendido_qtde =qtde[i]

print(nome)
print(qtde)
print(preco)
print(mais_vendido_nome)
print(mais_vendido_qtde)
# Out:
# ['meia', 'bone']
# [6, 13]
# [5.0, 2.0]
# bone
# 13

# %%
# o prgrama deve solictar ao usuário as seguintes infromações:
# temperatura
# pH da solução de cultura
# tempo de incubação

tmp = [] 
ph = []
tmp_inc = []

temperatura = int(input("Qual a temperatura da inubadora?"))
ph_cult  = float(input("Qual o pH da solução de cultura"))
tmp_incubacao = int(input("Qual o tempo de incubação em horas:"))

tmp = temperatura
ph = ph_cult
tmp_inc = tmp_incubacao

print(tmp)
print(ph)
print(tmp_inc)

if (tmp >=36 and tmp <= 39) and (ph >= 6.5 and ph <=7.5) and tmp_inc >= 18 and tmp_inc <= 24: 
    print("Todas as condições estão ideais")
elif (tmp < 36 and tmp > 39) and (ph < 6.5 and ph > 7.5) and tmp_inc < 18 and tmp_inc > 24:
    print("Todas as condições fora do ideal")    
else:
    print("Nem todas as condições estão ideais")
# Out:
# 34
# 5.5
# 15
# Nem todas as condições estão ideais
